# %%
import h5py
with h5py.File('/files/pathml/aim2/mediapipe_results/balance_test/heavy/uwisc/UWisc_7111_Balance.h5', 'r') as f:
    mb = f["motionBert_cropped_iou"]
    print(mb.shape)
    print(mb[0][3])
    print(f.keys())
# Out:
# (3330, 17, 4)
# [0.04296875 0.071253   0.00420165 1.        ]
# <KeysViewHDF5 ['224_augmented_dino_features', '512_dino_features', 'avg_frame', 'camera_mp_cropped', 'camera_mp_cropped_iou', 'camera_poses', 'camera_poses_labels', 'cvt_features', 'dinov2_features', 'dinov3_features', 'motionBert_cropped_iou', 'mvit_features', 'slowfast_features', 'soft_labels', 'static_box_coords', 'tolo_bbox_id', 'world_mp_cropped', 'world_mp_cropped_iou', 'world_poses', 'world_poses_labels', 'yolo_bbox', 'yolo_bbox_id', 'yolo_bbox_id_full']>
