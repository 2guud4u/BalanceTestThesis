# %%
import pandas as pd
import torch
import torch.nn.functional as F
import numpy as np
import h5py
import os
import sys
from tqdm import tqdm

# %%
# set path to outside directory

from network import FourLayerDinoNetwork
#get out 2 directories
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), "../")))
from dataloader import get_dino_dataset, create_val_train_splits, get_world_pose_dataset
from eval_helper import run_experiment, grid_search_hyperparameters
from Smoothing import majority_vote_past, majority_vote_future, thresholded_argmax, majority_vote_bidirectional
